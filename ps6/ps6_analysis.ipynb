# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

dir = ("data/Lehman_Brothers/part-00000.csv")
data_wide  = pd.read_csv(dir,sep=",")
data_wide["date"] = pd.to_datetime(data_wide['date'], format='%Y%m%d', errors='coerce')

# %%
data_wide["date"].head(20)
# Out:
# 0    2008-10-11
# 1    2008-11-14
# 2    2008-11-12
# 3    2008-12-24
# 4    2008-10-31
# 5    2008-12-06
# 6    2008-11-06
# 7    2008-10-22
# 8    2008-11-02
# 9    2008-10-14
# 10   2008-11-07
# 11   2008-12-26
# 12   2008-10-08
# 13   2008-11-26
# 14   2008-10-15
# 15   2008-12-02
# 16   2008-11-21
# 17   2008-11-08
# 18   2008-11-09
# 19   2008-10-31
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# # Print some standard graphs to get a sense of the data

# %% [markdown]
# According to a quick wikipedia search:
# "The filing for Chapter 11 bankruptcy protection by financial services firm Lehman Brothers on September 15, 2008, remains the largest bankruptcy filing in U.S. history, with Lehman holding over US$600,000,000,000 in assets"
#
# Lets see if there is some trend in the search of Lehman Brothers during this time of financial instability

# %%
plt.figure(figsize=(12,7))
plt.plot_date(data_wide["date"],data_wide['visits'], label = "visits")
plt.ylabel("Visits", fontsize = 12)
plt.xlabel("Date", fontsize = 12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# As expected there is a big jump in the data during the month where Lehman Brothers collapsed. During the month os September many ussers searched for this Lehman Brothers because it will likely affect their well being and financial security
